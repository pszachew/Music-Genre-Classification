# %%
from google.colab import drive
import sys
drive.mount('/content/gdrive')
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import os
import librosa
import pandas as pd

# %%
X = []
labels = []
path = '/content/gdrive/My Drive/Data/GTZAN/genres_original'
# path_out = '/content/gdrive/My Drive/Embedded Music'
for dir in os.listdir(path):
  for file in os.listdir(path+'/'+dir):
      src, sr = librosa.load(path+'/'+dir+'/'+file)
      mfcc = librosa.feature.mfcc(y=src, sr = sr, n_mfcc=20)
      dmfcc = mfcc[:, 1:] - mfcc[:, :-1]
      ddmfcc = dmfcc[:, 1:] - dmfcc[:, :-1]
      X.append(np.concatenate((np.mean(mfcc, axis=1), np.std(mfcc, axis=1),
                           np.mean(dmfcc, axis=1), np.std(dmfcc, axis=1),
                           np.mean(ddmfcc, axis=1), np.std(ddmfcc, axis=1))
                          , axis=0))
      labels.append(dir)

# %%
X_df = pd.DataFrame(X)
X_df
# Out:
#             0           1          2    ...       117       118       119
# 0   -238.919205  132.330872  -0.075443  ...  4.932839  5.267922  5.171993
# 1   -164.594574  142.707443 -41.489227  ...  5.178903  5.093446  5.460716
# 2   -241.794052   97.494850  -3.085955  ...  5.822574  5.569283  5.324561
# 3    -76.065048  101.082916 -11.607360  ...  5.518663  5.390641  4.866613
# 4   -223.386597  114.254135  -4.425039  ...  5.294652  5.690430  4.904774
# ..          ...         ...        ...  ...       ...       ...       ...
# 994 -156.618057   22.764700  10.472749  ...  4.370839  4.657853  4.444161
# 995 -299.332642   60.760708  32.089752  ...  3.629599  3.747277  3.742064
# 996 -294.042053   84.625092  39.086716  ...  3.558760  3.749126  3.713835
# 997 -315.025909  112.736259   9.766944  ...  4.587598  4.370592  4.480740
# 998 -340.980957   89.776741  44.569427  ...  4.029761  3.937084  4.010120
#
# [999 rows x 120 columns]

# %%
labels_df = pd.DataFrame(labels)

# %%
labels_df
# Out:
#           0
# 0    reggae
# 1    reggae
# 2    reggae
# 3    reggae
# 4    reggae
# ..      ...
# 994    jazz
# 995    jazz
# 996    jazz
# 997    jazz
# 998    jazz
#
# [999 rows x 1 columns]

# %%
X_df.to_csv("/content/gdrive/MyDrive/csv_data/GTZAN/features_mfcc.csv", index=None, header=None)

# %%
labels_df.to_csv("/content/gdrive/MyDrive/csv_data/GTZAN/labels_mfcc.csv", index=None, header=None)
