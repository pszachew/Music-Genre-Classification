# %%
from google.colab import drive
import sys
drive.mount('/content/gdrive')
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import os
import librosa
import pandas as pd

# %%
X = []
labels = []
path = '/content/gdrive/MyDrive/Data/IRMAS-TrainingData'
for dir in os.listdir(path):
  for file in os.listdir(path+'/'+dir):
      src, sr = librosa.load(path+'/'+dir+'/'+file)
      mfcc = librosa.feature.mfcc(y=src, sr = sr, n_mfcc=20)
      dmfcc = mfcc[:, 1:] - mfcc[:, :-1]
      ddmfcc = dmfcc[:, 1:] - dmfcc[:, :-1]
      X.append(np.concatenate((np.mean(mfcc, axis=1), np.std(mfcc, axis=1),
                           np.mean(dmfcc, axis=1), np.std(dmfcc, axis=1),
                           np.mean(ddmfcc, axis=1), np.std(ddmfcc, axis=1))
                          , axis=0))
      labels.append(dir)

# %%
X_df = pd.DataFrame(X)
X_df
# Out:
#              0           1          2    ...       117       118       119
# 0    -353.066101  238.182205 -21.906603  ...  3.711303  3.387791  3.281576
# 1    -265.742432  222.349854 -37.165188  ...  4.250201  4.143330  3.940315
# 2    -476.955811  229.792801  15.304705  ...  3.195652  3.234661  3.027251
# 3     -72.003830   97.428215 -36.069405  ...  4.701860  4.925610  4.678722
# 4     -81.792023  104.972252 -82.745056  ...  4.095572  4.878194  4.304366
# ...          ...         ...        ...  ...       ...       ...       ...
# 6700 -105.853088  142.841339  -8.828431  ...  4.460792  5.495020  4.610440
# 6701 -101.753372  152.571960  -8.922255  ...  4.387928  4.165952  4.460977
# 6702 -218.426392  111.908157  -7.530903  ...  3.900619  3.224931  3.412625
# 6703 -197.883774  109.424187  -5.542036  ...  4.035300  3.711323  3.491911
# 6704 -202.052872  114.041046 -11.645317  ...  4.098511  4.181062  3.792141
#
# [6705 rows x 120 columns]

# %%
labels_df = pd.DataFrame(labels)
labels_df
# Out:
#         0
# 0     pia
# 1     pia
# 2     pia
# 3     pia
# 4     pia
# ...   ...
# 6700  voi
# 6701  voi
# 6702  voi
# 6703  voi
# 6704  voi
#
# [6705 rows x 1 columns]

# %%
labels_df.to_csv("/content/gdrive/MyDrive/csv_data/IRMAS/labels_mfcc.csv", index=False, header=False)

# %%
X_df.to_csv("/content/gdrive/MyDrive/csv_data/IRMAS/labels_mfcc.csv", index=False, header=False)
